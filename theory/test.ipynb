# %%
{
 "cells": [
  {
   "cell_type": "markdown", 
   "source": [
    "# Geometric Interpretation of Linear Regression",
    "",
    "Equation: $$E = mc^2$$",
    "",
    "Inline: $\\nabla \\cdot E = \\frac{\\rho}{\\epsilon_0}$"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 4
}
